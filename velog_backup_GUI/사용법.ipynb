# %% [markdown]
# ## 처음 다운 받았을때
#
# ```bash
# git clone https://github.com/cjaewon/velog-backup
# cd velog-backup # 내 경로는 cd D:\Velog_backup\velog-backup
# npm install
# ```

# %% [markdown]
# ## 사용법 알아보기
#
# ```bash
# node app.js --help
# ```

# %% [markdown]
# ## 백업
#
# ```bash
# node app.js -u lak5000
# ```

# %%
import tkinter as tk
from tkinter import filedialog
from tkinter import messagebox
import os
import shutil
import subprocess
from datetime import datetime
from glob import glob
import schedule
import time

# 폴더 생성 함수
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSError:
        print ('Error: Creating directory. ' +  directory)
        
def VELOG_BACKUP(VelogBackup, MOVE_PATH, USER_NAME, DELAY, CERT):
    
    if MOVE_PATH == "":
        MOVE_PATH = VelogBackup
        
    # ROOT 폴더 경로
    ROOT_PATH = f"backup"

    # 대상 폴더 경로
    CONTENT_PATH = f"{ROOT_PATH}/content"

    # 이동 대상 폴더 경로
    SOURCE_PATH = f"{ROOT_PATH}/images"

    # 기존 backup 폴더 삭제
    if os.path.exists(ROOT_PATH):
        shutil.rmtree(ROOT_PATH)
    
    if DELAY != "":
        DELAY = f"-d {DELAY}"
        
    if CERT != "":
        CERT = f"-c {CERT}"

    # cmd 명령어 실행
    subprocess.run(['cmd', '/c', f'node {VelogBackup}/app.js -u {USER_NAME} {DELAY} {CERT}'])

    # 파일 이동
    shutil.move(SOURCE_PATH, CONTENT_PATH)

    # 대상 폴더 내의 모든 파일 경로 탐색

    MD_LIST = glob(f'{CONTENT_PATH}/*.md')

    for file_name in MD_LIST:
        # 파일 열기
        with open(file_name, 'r', encoding='UTF-8') as file:
            content = file.read()
            
        # 이미지 경로 변경
        new_content = content.replace(f'/images/', 'images/')
        
        # 변경된 내용 저장
        with open(file_name, 'w', encoding = 'UTF-8') as file:
            file.write(new_content)

    # backup/content 폴더 이름을 backup-유저명-날짜로 변경
    
    # 이동할 새 경로
    NEW_PATH = MOVE_PATH + f"/{USER_NAME}_velog_backup"
    createFolder(NEW_PATH)

    # 폴더 이동
    shutil.move(CONTENT_PATH, NEW_PATH)

    # 폴더 이름 변경
    os.rename(os.path.join(NEW_PATH, 'content'), os.path.join(NEW_PATH, f'velog_backup_{datetime.today().strftime("%Y%m%d_%H%M%S")}'))
    
    # backup 폴더 삭제
    shutil.rmtree(ROOT_PATH)

backup_path = ""
user_name = ""
backup_path2 = ""
delay = ""
cert = ""

def select_path():
    path = filedialog.askdirectory()
    path_label.configure(text=path)
    global backup_path
    backup_path = path_label.cget("text")
    
def display_ver():
    title_ver = subprocess.run(['cmd', '/c', f'cd {backup_path} & node app.js -V'])
    global title_ver_label
    title_ver_label.configure(text=title_ver)

def select_path2():
    path2 = filedialog.askdirectory()
    path_label2.configure(text=path2)
    global backup_path2
    backup_path2 = path_label2.cget("text")

def get_username(*args):
    text3 = username_input.get()
    username_label.configure(text=text3)
    global user_name
    user_name = username_label.cget("text")
    
def get_delay(*args):
    text4 = delay_input.get()
    delay_label.configure(text=text4)
    global delay
    delay = delay_label.cget("text")
    
def get_access_token(*args):
    text5 = access_token_input.get()
    access_token_label.configure(text=text5)
    global cert
    cert = access_token_label.cget("text")

def execute():
    # 실행할 코드 작성
    messagebox.showinfo("Velog Backup", f"백업이 {backup_path2}/{user_name}_velog_backup에 저장되었습니다.")

root = tk.Tk()

# 창 크기 설정
root.geometry("300x380")

# 창 이름 설정
root.title(f"Velog Backup")

# 경로 선택 창
path_button1 = tk.Button(root, text="Select velog-backup Path \n(app.js 파일이 들어있는 폴더를 선택해주세요.)", command=select_path)
path_label = tk.Label(root, text="")
path_button1.pack()
path_label.pack()

# 텍스트 입력 창 1
username_input = tk.Entry(root)
username_input.pack()
username_button = tk.Button(root, text="유저명 (필수 입력)", command=get_username)
username_label = tk.Label(root, text="")
username_button.pack()
username_label.pack()

# 텍스트 입력 창 2
delay_input = tk.Entry(root)
delay_input.pack()
delay_button = tk.Button(root, text="딜레이 (단위 ms, 글이 많은 경우 늘려주세요.\n기본값은 0입니다.)", command=get_delay)
delay_label = tk.Label(root, text="")
delay_button.pack()
delay_label.pack()

# 텍스트 입력 창 3
access_token_input = tk.Entry(root)
access_token_input.pack()
access_token_button = tk.Button(root, text="velog 유저 엑세스 토큰 \n(필요시 사용, 기본값은 공백입니다.)", command=get_access_token)
access_token_label = tk.Label(root, text="")
access_token_button.pack()
access_token_label.pack()


# 경로 선택 창
path_button2 = tk.Button(root, text="백업 폴더를 생성할 위치 \n(유저명_velog_backup으로 폴더가 생성됩니다.)", command=select_path2)
path_label2 = tk.Label(root, text="")
path_button2.pack()
path_label2.pack()

# 실행 버튼
execute_button = tk.Button(root, text="실행", command=lambda : (VELOG_BACKUP(backup_path, backup_path2, user_name, delay, cert), execute()))
execute_button.pack()

# GUI 창 실행
root.mainloop()
# Out:
# D:/BlueStack D:/BlueStack/BlueStacks X hgjk
# D:/BlueStack D:/BlueStack/BlueStacks X hgjk

# %%
# !pyinstaller --onefile velog_backupPy.py
# Out:
# 351 INFO: PyInstaller: 5.11.0
# 351 INFO: Python: 3.10.11
# 361 INFO: Platform: Windows-10-10.0.22621-SP0
# 362 INFO: wrote d:\Velog_backup\velog-backup\velog_backupPy.spec
# 364 INFO: UPX is not available.
# 366 INFO: Extending PYTHONPATH with paths
# ['d:\\Velog_backup\\velog-backup']
# 755 INFO: checking Analysis
# 806 INFO: Building because D:\Velog_backup\velog-backup\velog_backupPy.py changed
# 806 INFO: Initializing module dependency graph...
# 808 INFO: Caching module graph hooks...
# 825 INFO: Analyzing base_library.zip ...
# 2677 INFO: Loading module hook 'hook-heapq.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 2757 INFO: Loading module hook 'hook-encodings.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 4160 INFO: Loading module hook 'hook-pickle.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 5528 INFO: Caching module dependency graph...
# 5662 INFO: running Analysis Analysis-00.toc
# 5666 INFO: Adding Microsoft.Windows.Common-Controls to dependent assemblies of final executable
#   required by c:\Users\lak50\AppData\Local\Programs\Python\Python310\python.exe
# 5867 INFO: Analyzing d:\Velog_backup\velog-backup\velog_backupPy.py
# 6076 INFO: Loading module hook 'hook-pytz.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 6341 INFO: Loading module hook 'hook-pkg_resources.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 7720 INFO: Loading module hook 'hook-platform.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 7776 INFO: Loading module hook 'hook-xml.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 7816 INFO: Loading module hook 'hook-sysconfig.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 7904 INFO: Loading module hook 'hook-difflib.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 8467 INFO: Loading module hook 'hook-multiprocessing.util.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 8993 INFO: Processing module hooks...
# 9022 INFO: Processing pre-safe import module hook win32com from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\pre_safe_import_module\\hook-win32com.py'.
# 9110 INFO: Loading module hook 'hook-win32com.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 9111 INFO: Loading module hook 'hook-pythoncom.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 9413 INFO: Loading module hook 'hook-pywintypes.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\stdhooks'...
# 10245 INFO: Loading module hook 'hook-packaging.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 10370 INFO: Loading module hook 'hook-_tkinter.py' from 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks'...
# 10371 INFO: checking Tree
# 10405 INFO: checking Tree
# 10412 INFO: checking Tree
# 10886 INFO: Looking for ctypes DLLs
# 10891 INFO: Analyzing run-time hooks ...
# 10895 INFO: Including run-time hook 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_inspect.py'
# 10896 INFO: Including run-time hook 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgutil.py'
# 10898 INFO: Including run-time hook 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_multiprocessing.py'
# 10900 INFO: Including run-time hook 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_pkgres.py'
# 10904 INFO: Including run-time hook 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth_win32comgenpy.py'
# 10905 INFO: Including run-time hook 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pywintypes.py'
# 10906 INFO: Including run-time hook 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\_pyinstaller_hooks_contrib\\hooks\\rthooks\\pyi_rth_pythoncom.py'
# 10906 INFO: Including run-time hook 'c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\hooks\\rthooks\\pyi_rth__tkinter.py'
# 10960 INFO: Looking for dynamic libraries
# 391 INFO: Extra DLL search directories (AddDllDirectory): []
# 391 INFO: Extra DLL search directories (PATH): ['c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310', 'c:\\Users\\lak50\\AppData\\Roaming\\Python\\Python310\\Scripts', 'C:\\WINDOWS\\system32', 'C:\\WINDOWS', 'C:\\WINDOWS\\System32\\Wbem', 'C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\', 'C:\\WINDOWS\\System32\\OpenSSH\\', 'C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR', 'C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common', 'C:\\Program Files\\Microsoft SQL Server\\150\\Tools\\Binn\\', 'C:\\Program Files\\Microsoft SQL Server\\Client SDK\\ODBC\\170\\Tools\\Binn\\', 'C:\\Program Files\\dotnet\\', 'C:\\Program Files\\Git\\cmd', 'D:\\NodeJS\\', 'D:\\Anaconda', 'D:\\Anaconda\\Library\\mingw-w64\\bin', 'D:\\Anaconda\\Library\\usr\\bin', 'D:\\Anaconda\\Library\\bin', 'D:\\Anaconda\\Scripts', 'C:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\Scripts\\', 'C:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\', 'C:\\Users\\lak50\\AppData\\Local\\Microsoft\\WindowsApps', 'D:\\VSCode\\Microsoft VS Code\\bin', 'C:\\Users\\lak50\\.dotnet\\tools', 'C:\\Users\\lak50\\AppData\\Local\\GitHubDesktop\\bin', 'C:\\Users\\lak50\\AppData\\Roaming\\npm', 'C:\\WINDOWS\\system32', 'C:\\WINDOWS', 'C:\\WINDOWS\\System32\\Wbem', 'C:\\WINDOWS\\System32\\WindowsPowerShell\\v1.0\\', 'C:\\WINDOWS\\System32\\OpenSSH\\', 'C:\\Program Files\\NVIDIA Corporation\\NVIDIA NvDLISR', 'C:\\Program Files (x86)\\NVIDIA Corporation\\PhysX\\Common', 'C:\\Program Files\\Microsoft SQL Server\\150\\Tools\\Binn\\', 'C:\\Program Files\\Microsoft SQL Server\\Client SDK\\ODBC\\170\\Tools\\Binn\\', 'C:\\Program Files\\dotnet\\', 'C:\\Program Files\\Git\\cmd', 'D:\\NodeJS\\', 'D:\\Anaconda', 'D:\\Anaconda\\Library\\mingw-w64\\bin', 'D:\\Anaconda\\Library\\usr\\bin', 'D:\\Anaconda\\Library\\bin', 'D:\\Anaconda\\Scripts', 'C:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\Scripts\\', 'C:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\', 'C:\\Users\\lak50\\AppData\\Local\\Microsoft\\WindowsApps', 'D:\\VSCode\\Microsoft VS Code\\bin', 'C:\\Users\\lak50\\.dotnet\\tools', 'C:\\Users\\lak50\\AppData\\Local\\GitHubDesktop\\bin', 'C:\\Users\\lak50\\AppData\\Roaming\\npm']
# 11977 INFO: Looking for eggs
# 11992 INFO: Using Python library c:\Users\lak50\AppData\Local\Programs\Python\Python310\python310.dll
# 11992 INFO: Found binding redirects:
# []
# 11995 INFO: Warnings written to d:\Velog_backup\velog-backup\build\velog_backupPy\warn-velog_backupPy.txt
# 12041 INFO: Graph cross-reference written to d:\Velog_backup\velog-backup\build\velog_backupPy\xref-velog_backupPy.html
# 12092 INFO: checking PYZ
# 12136 INFO: checking PKG
# 12180 INFO: Building because toc changed
# 12180 INFO: Building PKG (CArchive) velog_backupPy.pkg
# 15723 INFO: Building PKG (CArchive) velog_backupPy.pkg completed successfully.
# 15762 INFO: Bootloader c:\Users\lak50\AppData\Local\Programs\Python\Python310\lib\site-packages\PyInstaller\bootloader\Windows-64bit-intel\run.exe
# 15762 INFO: checking EXE
# 15795 INFO: Building because toc changed
# 15795 INFO: Building EXE from EXE-00.toc
# 15797 INFO: Copying bootloader EXE to d:\Velog_backup\velog-backup\dist\velog_backupPy.exe.notanexecutable
# 15826 INFO: Copying icon to EXE
# 15826 INFO: Copying icons from ['c:\\Users\\lak50\\AppData\\Local\\Programs\\Python\\Python310\\lib\\site-packages\\PyInstaller\\bootloader\\images\\icon-console.ico']
# 15851 INFO: Writing RT_GROUP_ICON 0 resource with 104 bytes
# 15851 INFO: Writing RT_ICON 1 resource with 3752 bytes
# 15851 INFO: Writing RT_ICON 2 resource with 2216 bytes
# 15851 INFO: Writing RT_ICON 3 resource with 1384 bytes
# 15851 INFO: Writing RT_ICON 4 resource with 37019 bytes
# 15851 INFO: Writing RT_ICON 5 resource with 9640 bytes
# 15851 INFO: Writing RT_ICON 6 resource with 4264 bytes
# 15851 INFO: Writing RT_ICON 7 resource with 1128 bytes
# 15853 INFO: Copying 0 resources to EXE
# 15854 INFO: Embedding manifest in EXE
# 15854 INFO: Updating manifest in d:\Velog_backup\velog-backup\dist\velog_backupPy.exe.notanexecutable
# 15879 INFO: Updating resource type 24 name 1 language 0
# 15882 INFO: Appending PKG archive to EXE
# 15897 INFO: Fixing EXE headers
# 17330 INFO: Building EXE from EXE-00.toc completed successfully.
